# %%
# Install the streamlit and plotly packages
# %pip3 install streamlit
# %pip3 install plotly
# %pip3 install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/Grace/Downloads/3:10/web_app/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/Grace/Downloads/3:10/web_app/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# ...

# %%
import pandas as pd

# %%
vehicle_df = pd.read_csv('/Users/Grace/Downloads/3:10/web_app/.venv/vehicles_us.csv')

# %%
vehicle_df.head(20)
# Out:
#     price  model_year                     model  condition  cylinders fuel  \
# 0    9400      2011.0                    bmw x5       good        6.0  gas
# 1   25500         NaN                ford f-150       good        6.0  gas
# 2    5500      2013.0            hyundai sonata   like new        4.0  gas
# 3    1500      2003.0                ford f-150       fair        8.0  gas
# 4   14900      2017.0              chrysler 200  excellent        4.0  gas
# 5   14990      2014.0              chrysler 300  excellent        6.0  gas
# 6   12990      2015.0              toyota camry  excellent        4.0  gas
# 7   15990      2013.0               honda pilot  excellent        6.0  gas
# 8   11500      2012.0               kia sorento  excellent        4.0  gas
# 9    9200      2008.0               honda pilot  excellent        NaN  gas
# 10  19500      2011.0  chevrolet silverado 1500  excellent        8.0  gas
# ...

# %%
vehicle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
vehicle_df['is_4wd'] = vehicle_df['is_4wd'].astype('bool')

# %%
vehicle_df.isna().sum()
# Out:
# price              0
# model_year      3619
# model              0
# condition          0
# cylinders       5260
# fuel               0
# odometer        7892
# transmission       0
# type               0
# paint_color     9267
# is_4wd             0
# date_posted        0
# days_listed        0
# dtype: int64

# %%
vehicle_df.dropna(inplace=True)

# %%
vehicle_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
vehicle_df['model_year'] = vehicle_df['model_year'].astype(int)

# %%
vehicle_df['odometer'] = vehicle_df['odometer'].astype(int)

# %%
vehicle_df['date_posted'] = pd.to_datetime(vehicle_df['date_posted'])

# %%
vehicle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29916 entries, 2 to 51523
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         29916 non-null  int64
#  1   model_year    29916 non-null  int64
#  2   model         29916 non-null  object
#  3   condition     29916 non-null  object
#  4   cylinders     29916 non-null  float64
#  5   fuel          29916 non-null  object
#  6   odometer      29916 non-null  int64
#  7   transmission  29916 non-null  object
#  8   type          29916 non-null  object
#  9   paint_color   29916 non-null  object
#  10  is_4wd        29916 non-null  bool
#  11  date_posted   29916 non-null  datetime64[ns]
#  12  days_listed   29916 non-null  int64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(4), object(6)
# memory usage: 3.0+ MB

# %%
vehicle_df.sample(20)
# Out:
#        price  model_year                     model  condition  cylinders fuel  \
# 3968   13250        2013                ford f-250  excellent        8.0  gas
# 39230   4999        2007          volkswagen jetta   like new        5.0  gas
# 6791   32500        2018       chevrolet silverado        new        8.0  gas
# 45461  18200        2013             dodge charger  excellent        8.0  gas
# 9966    5795        2012            subaru impreza  excellent        4.0  gas
# 16033   5700        2007           subaru forester       good        4.0  gas
# 39643   5700        2013             nissan altima       good        6.0  gas
# 6870    2700        2005                  ram 1500    salvage        8.0  gas
# 41829  15000        2006                ford f-150       good        8.0  gas
# 32830   1500        2005         volkswagen passat       fair        6.0  gas
# 39724  13995        2008  chevrolet silverado 1500  excellent        8.0  gas
# ...

# %%
import plotly.express as px
import streamlit as st

# %%
st.header('Price Distribution') 
st.write('The price distribution of the vehicles is shown below.')
fig=px.histogram(vehicle_df, x='price', title='Price Distribution')
st.plotly_chart(fig)
# Out:
# 2025-03-11 10:57:13.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:57:13.694 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:57:13.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:57:13.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:57:13.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:57:13.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:57:13.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
st.header('Vehicle model year vs price')
st.write('The relationship between vehicle model year and price is shown below.')
fig=px.scatter(vehicle_df, x='model_year', y='price', title='Vehicle model year vs price')
st.plotly_chart(fig)
# Out:
# 2025-03-11 10:58:33.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:58:33.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:58:33.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:58:33.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:58:33.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:58:33.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:58:33.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
st.header('Vehicle manufacturer vs price')
st.write('The relationship between vehicle manufacturer and price is shown below.')
manufacturer = vehicle_df['model'].s
fig=px.bar(vehicle_df, x='manufacturer', y='price', title='Vehicle manufacturer vs price')
st.plotly_chart(fig)
# Out:
# 2025-03-11 10:59:11.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:59:11.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:59:11.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:59:11.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:59:11.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-11 10:59:11.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 3
#       1 st.header('Vehicle manufacturer vs price')
# ...
